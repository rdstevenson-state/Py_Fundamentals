# %% [markdown]
# <h4> Title: Python Fundamentals Introduction to Jupyter </h4>
# <p> Name: Rachel Stevenson </p>
# <p> Date: July 1st 2022 </p>
# <p> Purpose: Introducing Jupyter Notebook to Students </p>

# %%
# Step 1: Import packages into jupyter notebook  and import data 
import pandas as pd 
# import geopandas as gpd 
import numpy as np

# %%
# Step 2: Bringing In Data 
# data_python = r"C:\Users\rstevenson\Desktop\Desktop Folders\DHSEM\Python Scripts\Data_for_Python"
data_python_rel = r".\CI_CDOT_20210610.csv"
data_python = pd.read_csv(data_python_rel)
data_python.head()
# Out:
#                 Typology Department           Occupancy OrgID Building Number  \
# 0  Government Facilities       CDOT           Sand Shed   HAA             NaN
# 1  Government Facilities       CDOT        Storage Shed   HAA             NaN
# 2  Government Facilities       CDOT        Storage Shed   HAA             NaN
# 3  Government Facilities       CDOT        Storage Shed   HAA             NaN
# 4  Government Facilities       CDOT  Maintenance/Repair   HAA     G05-000-001
#
#                                   Name                    Street1     City  \
# 0  Agate Metal Building Sand Shed 2017               39100 CR 166    Agate
# 1                   Agate Storage Shed               39100 CR 166    Agate
# 2        Agate Metal Storage Container      39100 County Road 166    Agate
# 3              Agate Wood Storage Shed               39100 CR 166    Agate
# 4           Aguilar Maintenance Garage  121 W. Main, 25A Frontage  Aguilar
#
# ...
